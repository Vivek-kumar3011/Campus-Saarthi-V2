# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/vivekkumar30112006/hepatic-checkpoint/training_checkpoint.pth
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/._Task08_HepaticVessel
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/._labelsTr
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/._imagesTr
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/._imagesTs
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/._dataset.json
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/dataset.json
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_204.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_060.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_130.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_451.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_292.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_014.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_376.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_169.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_037.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_387.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_118.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_310.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_301.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_415.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_012.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_439.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_130.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_074.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_392.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_074.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_036.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_055.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_428.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_339.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_342.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_426.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_313.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_247.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_003.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_076.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_354.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_043.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_024.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_366.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_457.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_435.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_410.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_035.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_360.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_063.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_015.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_331.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_120.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_017.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_370.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_182.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_109.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_414.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_009.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_188.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_264.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_120.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_317.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_415.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_243.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_430.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_418.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_304.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_292.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_435.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_162.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_202.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_134.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_180.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_247.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_451.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_365.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_105.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_107.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_343.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_460.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_056.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_153.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_450.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_135.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_036.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_251.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_109.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_277.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_162.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_414.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_306.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_315.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_156.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_054.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_034.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_328.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_390.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_012.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_264.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_430.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_126.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_135.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_024.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_134.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_069.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_328.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_399.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_055.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_364.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_190.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_304.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_216.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_014.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_380.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_421.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_143.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_250.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_439.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_060.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_212.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_310.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_252.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_387.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_357.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_395.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_312.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_220.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_176.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_390.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_261.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_366.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_312.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_038.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_106.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_428.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_041.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_095.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_107.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_302.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_187.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_056.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_064.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_156.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_355.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_452.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_035.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_381.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_298.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_316.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_326.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_436.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_351.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_331.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_191.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_426.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_417.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_403.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_153.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_394.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_377.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_243.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_170.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_370.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_410.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_106.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_460.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_342.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_337.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_315.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_334.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_352.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_216.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_450.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_017.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_298.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_421.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_302.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_170.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_254.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_326.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_351.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_352.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_267.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_276.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_347.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_360.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_306.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_376.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_064.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_334.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_364.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_232.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_313.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_252.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_045.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_054.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_355.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_095.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_168.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_169.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_251.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_261.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_187.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_380.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_395.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_241.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_168.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_188.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_267.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_122.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_073.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_034.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_114.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_212.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_205.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_202.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_101.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_316.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_122.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_176.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_063.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_394.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_403.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_277.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_021.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_118.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_048.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_047.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_045.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_009.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_099.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_099.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_101.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_126.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_276.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_037.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_114.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_003.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_038.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_254.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_048.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_448.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_273.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_047.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_452.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_205.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_381.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_436.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_021.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_417.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_149.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_076.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_105.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_354.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_346.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_228.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_347.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_343.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_418.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_232.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_339.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_220.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_149.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_392.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_204.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_346.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_228.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_317.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_190.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_191.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_448.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_457.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_241.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_399.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_041.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_337.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_365.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_301.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_043.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_377.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_273.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_015.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_250.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_143.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_069.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_357.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_182.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/._hepaticvessel_073.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTs/hepaticvessel_180.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_033.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_383.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_016.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_028.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_396.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_378.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_068.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_029.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_335.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_255.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_290.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_193.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_100.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_372.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_042.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_256.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_032.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_271.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_110.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_336.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_268.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_117.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_221.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_437.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_208.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_210.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_181.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_161.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_184.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_333.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_004.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_368.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_083.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_389.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_290.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_440.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_385.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_123.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_263.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_362.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_458.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_199.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_456.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_332.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_147.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_244.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_132.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_085.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_129.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_258.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_211.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_061.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_179.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_420.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_082.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_272.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_096.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_167.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_400.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_201.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_110.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_098.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_348.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_113.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_131.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_271.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_345.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_096.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_080.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_111.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_175.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_219.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_097.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_027.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_103.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_229.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_233.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_092.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_341.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_282.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_174.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_010.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_319.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_235.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_016.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_307.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_158.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_287.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_079.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_157.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_262.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_147.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_093.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_255.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_422.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_083.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_248.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_011.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_235.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_052.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_164.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_429.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_327.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_215.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_397.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_231.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_231.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_374.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_137.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_341.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_423.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_234.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_293.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_427.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_242.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_214.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_332.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_274.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_269.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_008.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_278.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_133.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/._hepaticvessel_314.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_132.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_294.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/labelsTr/hepaticvessel_159.nii
# ...
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_362.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_203.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_389.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_384.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_025.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_284.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_166.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_027.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_203.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_322.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_385.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_227.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_223.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_093.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_259.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_280.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_432.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_279.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_215.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_308.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_325.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_438.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_185.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_151.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_196.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_084.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_146.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_090.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_117.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_206.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_067.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_318.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_026.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_244.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_270.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_075.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_353.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_186.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_434.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_393.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_361.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_030.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_266.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_268.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_019.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_186.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_139.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_437.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_077.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_361.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_091.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_324.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_053.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_269.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_098.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_230.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_146.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_336.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_432.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_104.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_050.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_090.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_057.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_443.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_163.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_144.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_160.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_279.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_350.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_137.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_198.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_089.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_245.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_335.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_022.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_031.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_329.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_210.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_398.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_072.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_072.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_094.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_029.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_248.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_453.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_318.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_391.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_225.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_373.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_198.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_039.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_221.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_197.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_374.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_296.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_404.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_345.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_057.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_258.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_348.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_081.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_363.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_108.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_320.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_121.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_246.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_197.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_209.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_236.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_200.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_018.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_218.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_356.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_286.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_237.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_412.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_059.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_340.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_240.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_227.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_401.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_237.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_445.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_185.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_327.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_150.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_177.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_189.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_308.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_429.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_262.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_077.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_299.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/._hepaticvessel_125.nii.gz
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_456.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_373.nii
# /kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel/imagesTr/hepaticvessel_058.nii

# %%
import os

# MUST be set before torch is imported — prevents GPU memory fragmentation
os.environ['PYTORCH_ALLOC_CONF'] = 'expandable_segments:True'

import torch

print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")

if torch.cuda.is_available():
    cap   = torch.cuda.get_device_capability(0)
    name  = torch.cuda.get_device_name(0)
    vram  = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"GPU     : {name}")
    print(f"Compute : sm_{cap[0]}{cap[1]}")
    print(f"VRAM    : {vram:.1f} GB")
    if cap[0] < 7:
        print("WARNING: GPU too old. Switch to T4 in Session Options.")
    else:
        print("GPU OK.")
else:
    print("No GPU — enable GPU in Kaggle Session Options.")

# %%
# !pip install -q monai nibabel tqdm
print("Libraries installed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 28.9 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 101.8 MB/s eta 0:00:0000:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Libraries installed.

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
from torch.optim.lr_scheduler import LinearLR, CosineAnnealingLR, SequentialLR

from monai.config import print_config
from monai.losses import DiceCELoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import SwinUNETR
from monai.data import DataLoader, Dataset, decollate_batch
from monai.utils import first
from monai.transforms import (
    AsDiscrete,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandFlipd,
    RandCropByPosNegLabeld,
    RandShiftIntensityd,
    ScaleIntensityRanged,
    Spacingd,
    RandRotate90d,
    EnsureTyped,
    RandGaussianNoised,
    RandScaleIntensityd,
    RandAdjustContrastd,
    RandZoomd,
)

print_config()
print(f"\nPyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU     : {torch.cuda.get_device_name(0)}")
# Out:
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# 2026-06-01 08:12:36.616884: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780301556.865896      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780301556.934441      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780301557.525170      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780301557.525215      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780301557.525218      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780301557.525221      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# MONAI version: 1.5.2
# Numpy version: 2.4.6
# Pytorch version: 2.10.0+cu128
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d18565fb3e4fd8c556707f91ac280a2dc3f681c1
# MONAI __file__: /usr/local/lib/python3.12/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.4
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.4.2
# scikit-image version: 0.25.2
# scipy version: 1.16.3
# Pillow version: 11.3.0
# Tensorboard version: 2.19.0
# gdown version: 5.2.1
# TorchVision version: 0.25.0+cu128
# tqdm version: 4.67.3
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.5
# pandas version: 2.3.3
# einops version: 0.8.2
# transformers version: 5.0.0
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
#
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4

# %%
# ── Dataset location ──────────────────────────────────────────────────────────
DATA_ROOT = '/kaggle/input/datasets/isobelmackie/msd-task08-hepatic-vessel/Task08_HepaticVessel'

# ── Output directory (persists between Kaggle sessions) ───────────────────────
WORK_DIR = '/kaggle/working/'
os.makedirs(WORK_DIR, exist_ok=True)

CHECKPOINT_PATH = os.path.join(WORK_DIR, 'training_checkpoint.pth')
BEST_MODEL_PATH = os.path.join(WORK_DIR, 'best_metric_model.pth')

# ── Pretrained weights ─────────────────────────────────────────────────────────
# Leave as empty string if not available — model trains from scratch
# To add: download model_swinvit.pt, create a Kaggle dataset, add it here
PRETRAINED_WEIGHTS = ''
# PRETRAINED_WEIGHTS = '/kaggle/input/swinvit-weights/model_swinvit.pt'

# ── Training hyperparameters ───────────────────────────────────────────────────
NUM_CLASSES    = 3        # background(0), vessel(1), tumor(2)
num_samples    = 2        # patches per volume per step (2 = fits in T4 16GB)
max_iterations = 5000   # total steps for full research run
eval_num       = 500      # validate and save checkpoint every N steps
warmup_steps   = 500      # linear LR warmup for first 500 steps

# ── Read dataset.json for official image/label pairs ──────────────────────────
with open(os.path.join(DATA_ROOT, 'dataset.json')) as f:
    dataset_info = json.load(f)

print('Dataset :', dataset_info.get('name'))
print('Labels  :', dataset_info.get('labels', {}))

def resolve_path(relative_path):
    """Convert relative path from dataset.json to absolute path.
    Handles both .nii and .nii.gz extensions."""
    rel  = relative_path.lstrip('./')
    full = os.path.join(DATA_ROOT, rel)
    if os.path.exists(full): return full
    if full.endswith('.gz') and os.path.exists(full[:-3]): return full[:-3]
    if not full.endswith('.gz') and os.path.exists(full + '.gz'): return full + '.gz'
    return full

all_files = []
for entry in dataset_info.get('training', []):
    img = resolve_path(entry['image'])
    lbl = resolve_path(entry['label'])
    if os.path.exists(img) and os.path.exists(lbl):
        all_files.append({'image': img, 'label': lbl})

# Last 20 cases for validation, rest for training
VAL_SIZE    = 20
train_files = all_files[:-VAL_SIZE]
val_files   = all_files[-VAL_SIZE:]

print(f"\nTotal pairs   : {len(all_files)}")
print(f"Training      : {len(train_files)}")
print(f"Validation    : {len(val_files)}")
print(f"\nCheckpoint    : {CHECKPOINT_PATH}")
print(f"Best model    : {BEST_MODEL_PATH}")
print(f"Max steps     : {max_iterations}")
print(f"Eval every    : {eval_num} steps")
# Out:
# Dataset : HepaticVessel
# Labels  : {'0': 'background', '1': 'Vessel', '2': 'Tumour'}
#
# Total pairs   : 303
# Training      : 283
# Validation    : 20
#
# Checkpoint    : /kaggle/working/training_checkpoint.pth
# Best model    : /kaggle/working/best_metric_model.pth
# Max steps     : 5000
# Eval every    : 500 steps

# %%
# Visualization only — raw load, no preprocessing
orig_transforms = Compose([
    LoadImaged(keys=['image', 'label'], ensure_channel_first=True),
    EnsureTyped(keys=['image', 'label'], track_meta=False),
])

# Full training pipeline — preprocessing + augmentation
train_transforms = Compose([
    LoadImaged(keys=['image', 'label'], ensure_channel_first=True),

    # HU range [-175, 250]: standard hepatic vessel window
    # Old range [0, 230] was too narrow and cut off important vessel signal
    ScaleIntensityRanged(
        keys=['image'],
        a_min=-175, a_max=250,
        b_min=0.0,  b_max=1.0,
        clip=True,
    ),

    # Remove large black border around patient body
    CropForegroundd(keys=['image', 'label'], source_key='image'),

    # Reorient to RAS standard (Right-Anterior-Superior)
    Orientationd(keys=['image', 'label'], axcodes='RAS'),

    # Resample to 1mm isotropic spacing
    # bilinear for image (smooth), nearest for label (preserves class IDs)
    Spacingd(
        keys=['image', 'label'],
        pixdim=(1.0, 1.0, 1.0),
        mode=('bilinear', 'nearest'),
    ),

    EnsureTyped(keys=['image', 'label'], track_meta=False),

    # Extract 2 random patches of 96x96x96 per volume
    # pos=1, neg=1: 50% patches centered on vessel/tumor, 50% on background
    # num_samples=2 fits in T4 16GB; use 4 if you have more GPU memory
    RandCropByPosNegLabeld(
        keys=['image', 'label'],
        label_key='label',
        spatial_size=(96, 96, 96),
        pos=1, neg=1,
        num_samples=num_samples,
        image_key='image',
        image_threshold=0,
    ),

    # Spatial augmentation
    RandFlipd(keys=['image', 'label'], spatial_axis=[0], prob=0.5),
    RandFlipd(keys=['image', 'label'], spatial_axis=[1], prob=0.5),
    RandFlipd(keys=['image', 'label'], spatial_axis=[2], prob=0.5),
    RandRotate90d(keys=['image', 'label'], prob=0.25, max_k=3),
    RandZoomd(
        keys=['image', 'label'],
        min_zoom=0.9, max_zoom=1.1,
        prob=0.3,
        mode=('trilinear', 'nearest'),
    ),

    # Intensity augmentation — simulates scanner differences between hospitals
    RandShiftIntensityd(keys=['image'], offsets=0.10, prob=0.5),
    RandScaleIntensityd(keys=['image'], factors=0.15, prob=0.5),
    RandAdjustContrastd(keys=['image'], prob=0.3, gamma=(0.7, 1.5)),
    RandGaussianNoised(keys=['image'], prob=0.15, mean=0.0, std=0.01),
])

# Validation: same preprocessing but NO augmentation
# track_meta=True so we can read filename for visualization
val_transforms = Compose([
    LoadImaged(keys=['image', 'label'], ensure_channel_first=True),
    ScaleIntensityRanged(
        keys=['image'],
        a_min=-175, a_max=250,
        b_min=0.0,  b_max=1.0,
        clip=True,
    ),
    CropForegroundd(keys=['image', 'label'], source_key='image'),
    Orientationd(keys=['image', 'label'], axcodes='RAS'),
    Spacingd(
        keys=['image', 'label'],
        pixdim=(1.0, 1.0, 1.0),
        mode=('bilinear', 'nearest'),
    ),
    EnsureTyped(keys=['image', 'label'], track_meta=True),
])

print("Transforms defined.")
print(f"  Training   : {len(train_transforms.transforms)} transforms (preprocessing + augmentation)")
print(f"  Validation : {len(val_transforms.transforms)} transforms (preprocessing only)")
# Out:
# Transforms defined.
#   Training   : 16 transforms (preprocessing + augmentation)
#   Validation : 6 transforms (preprocessing only)
# /usr/local/lib/python3.12/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.spatial.dictionary Orientationd.__init__:labels: Current default value of argument `labels=(('L', 'R'), ('P', 'A'), ('I', 'S'))` was changed in version None from `labels=(('L', 'R'), ('P', 'A'), ('I', 'S'))` to `labels=None`. Default value changed to None meaning that the transform now uses the 'space' of a meta-tensor, if applicable, to determine appropriate axis labels.
#   warn_deprecated(argname, msg, warning_category)

# %%
orig_ds     = Dataset(data=train_files, transform=orig_transforms)
orig_loader = DataLoader(orig_ds, batch_size=1, num_workers=2)

train_ds     = Dataset(data=train_files, transform=train_transforms)
train_loader = DataLoader(
    train_ds, batch_size=1, shuffle=True,
    num_workers=0, pin_memory=True
)

val_ds     = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(
    val_ds, batch_size=1,
    num_workers=2, pin_memory=True
)

print(f"Training dataset   : {len(train_ds)} volumes")
print(f"Validation dataset : {len(val_ds)} volumes")
print(f"Patches per epoch  : {len(train_ds) * num_samples} ({len(train_ds)} volumes × {num_samples} patches)")
# Out:
# Training dataset   : 283 volumes
# Validation dataset : 20 volumes
# Patches per epoch  : 566 (283 volumes × 2 patches)

# %%
orig_patient = first(orig_loader)
test_patient = first(train_loader)

print(f"Original shape    : {orig_patient['image'].shape}   (batch, channel, H, W, D)")
print(f"Preprocessed shape: {test_patient['image'].shape}  ({num_samples} patches, channel, 96, 96, 96)")

depth  = orig_patient['image'].shape[-1]
slices = depth // 2
print(f"Visualizing slice {slices} of {depth}")

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].set_title("Original CT (raw HU)")
axes[0].imshow(orig_patient['image'][0, 0, :, :, slices], cmap='gray')
axes[0].axis('off')

axes[1].set_title("After preprocessing\nHU [-175,250] → [0,1]")
axes[1].imshow(test_patient['image'][0, 0, :, :, slices], cmap='gray')
axes[1].axis('off')

axes[2].set_title("Label mask\n0=Background  1=Vessel  2=Tumor")
im = axes[2].imshow(
    test_patient['label'][0, 0, :, :, slices],
    cmap='nipy_spectral', vmin=0, vmax=2
)
plt.colorbar(im, ax=axes[2], shrink=0.8)
axes[2].axis('off')

plt.tight_layout()
plt.savefig(os.path.join(WORK_DIR, 'sample_visualization.png'), dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved to {WORK_DIR}")
# Out:
# Original shape    : torch.Size([1, 1, 512, 512, 49])   (batch, channel, H, W, D)
# Preprocessed shape: torch.Size([2, 1, 96, 96, 96])  (2 patches, channel, 96, 96, 96)
# Visualizing slice 24 of 49
# Saved to /kaggle/working/

# %%
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

# Build model
# Note: MONAI 1.4+ removed img_size from __init__ — model infers it from input
model = SwinUNETR(
    in_channels=1,
    out_channels=3,
    feature_size=48,
    use_checkpoint=True,
).to(device)

# Load pretrained weights if available and valid (>100MB file)
weight_valid = (
    PRETRAINED_WEIGHTS != '' and
    os.path.exists(PRETRAINED_WEIGHTS) and
    os.path.getsize(PRETRAINED_WEIGHTS) > 100 * 1024 * 1024
)

if weight_valid:
    size = os.path.getsize(PRETRAINED_WEIGHTS) / 1e6
    print(f"Loading pretrained SwinViT weights ({size:.0f} MB)...")
    weights = torch.load(PRETRAINED_WEIGHTS, map_location=device)
    model.load_from(weights=weights)
    print("Pretrained backbone loaded — model has strong starting point.")
    print("Expected Dice improvement: +0.08 to +0.12 over training from scratch.")
elif PRETRAINED_WEIGHTS != '' and os.path.exists(PRETRAINED_WEIGHTS):
    size = os.path.getsize(PRETRAINED_WEIGHTS) / 1e6
    print(f"Found weights file but only {size:.1f} MB — incomplete download, skipping.")
    if size < 1:
        os.remove(PRETRAINED_WEIGHTS)
        print("Deleted empty/corrupt file.")
    print("Training from scratch.")
else:
    print("No pretrained weights — training from scratch.")
    print("Set PRETRAINED_WEIGHTS path in Cell 3 if you have model_swinvit.pt")

total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal parameters    : {total:,}")
print(f"Trainable parameters: {trainable:,}")
print(f"Approx GPU memory   : ~{total * 4 / 1e9:.1f} GB (FP32) / ~{total * 2 / 1e9:.1f} GB (FP16)")
# Out:
# Device: cuda
# No pretrained weights — training from scratch.
# Set PRETRAINED_WEIGHTS path in Cell 3 if you have model_swinvit.pt
#
# Total parameters    : 62,186,757
# Trainable parameters: 62,186,757
# Approx GPU memory   : ~0.2 GB (FP32) / ~0.1 GB (FP16)

# %%
torch.backends.cudnn.benchmark = True  # faster training with fixed input size

# Loss: Dice handles class imbalance, CE gives stable gradients
loss_function = DiceCELoss(to_onehot_y=True, softmax=True)

# Optimizer: AdamW with weight decay regularization
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-5,
)

# Mixed precision scaler — FP16 training for memory efficiency and speed
scaler = torch.amp.GradScaler('cuda')

# Metric helpers
post_label      = AsDiscrete(to_onehot=NUM_CLASSES)
post_pred       = AsDiscrete(argmax=True, to_onehot=NUM_CLASSES)
dice_metric     = DiceMetric(include_background=True, reduction='mean',       get_not_nans=False)
dice_metric_cls = DiceMetric(include_background=True, reduction='mean_batch', get_not_nans=False)

# LR schedule: linear warmup then cosine decay
warmup_sched = LinearLR(
    optimizer, start_factor=0.1, end_factor=1.0, total_iters=warmup_steps
)
cosine_sched = CosineAnnealingLR(
    optimizer, T_max=max_iterations - warmup_steps, eta_min=1e-6
)
scheduler = SequentialLR(
    optimizer,
    schedulers=[warmup_sched, cosine_sched],
    milestones=[warmup_steps]
)

print("Loss, optimizer, and schedule configured.")
print(f"  Loss          : DiceCELoss")
print(f"  Optimizer     : AdamW  lr=1e-4  wd=1e-5")
print(f"  LR warmup     : steps 0 → {warmup_steps}  (1e-5 → 1e-4)")
print(f"  LR cosine     : steps {warmup_steps} → {max_iterations}  (1e-4 → 1e-6)")
print(f"  Grad clipping : max_norm=1.0")
print(f"  Mixed prec    : FP16 via GradScaler")
# Out:
# Loss, optimizer, and schedule configured.
#   Loss          : DiceCELoss
#   Optimizer     : AdamW  lr=1e-4  wd=1e-5
#   LR warmup     : steps 0 → 500  (1e-5 → 1e-4)
#   LR cosine     : steps 500 → 5000  (1e-4 → 1e-6)
#   Grad clipping : max_norm=1.0
#   Mixed prec    : FP16 via GradScaler

# %%
def save_checkpoint(global_step, dice_val_best, global_step_best,
                    epoch_loss_values, metric_values, class_dice_history):
    """Save complete training state. Called every eval_num steps."""
    torch.save({
        'global_step'          : global_step,
        'model_state_dict'     : model.state_dict(),
        'optimizer_state_dict' : optimizer.state_dict(),
        'scaler_state_dict'    : scaler.state_dict(),
        'scheduler_state_dict' : scheduler.state_dict(),
        'dice_val_best'        : dice_val_best,
        'global_step_best'     : global_step_best,
        'epoch_loss_values'    : epoch_loss_values,
        'metric_values'        : metric_values,
        'class_dice_history'   : class_dice_history,
    }, CHECKPOINT_PATH)
    size = os.path.getsize(CHECKPOINT_PATH) / 1e6
    print(f"  Checkpoint saved → {CHECKPOINT_PATH}  ({size:.0f} MB)")


def load_checkpoint():
    """Search multiple locations for checkpoint and resume if found."""
    # Check these paths in order
    search_paths = [
    '/kaggle/input/datasets/vivekkumar30112006/hepatic-checkpoint/training_checkpoint.pth',  # ADD THIS LINE
    CHECKPOINT_PATH,
    '/kaggle/input/hepatic-checkpoint/training_checkpoint.pth',
    '/kaggle/input/hepatic-vessel-checkpoint/training_checkpoint.pth',
]

    found = None
    for path in search_paths:
        if os.path.exists(path) and os.path.getsize(path) > 10000:
            found = path
            break

    if found:
        print(f"Checkpoint found : {found}")
        print(f"File size        : {os.path.getsize(found)/1e6:.0f} MB")
        ckpt = torch.load(found, map_location=device)
        model.load_state_dict(ckpt['model_state_dict'])
        optimizer.load_state_dict(ckpt['optimizer_state_dict'])
        scaler.load_state_dict(ckpt['scaler_state_dict'])
        scheduler.load_state_dict(ckpt['scheduler_state_dict'])
        global_step        = ckpt['global_step']
        dice_val_best      = ckpt['dice_val_best']
        global_step_best   = ckpt['global_step_best']
        epoch_loss_values  = ckpt['epoch_loss_values']
        metric_values      = ckpt['metric_values']
        class_dice_history = ckpt.get('class_dice_history', [])
        print(f"Resuming from step {global_step} | Best Dice so far: {dice_val_best:.4f}")
        return global_step, dice_val_best, global_step_best, epoch_loss_values, metric_values, class_dice_history
    else:
        print("No checkpoint found — starting fresh from step 0.")
        return 0, 0.0, 0, [], [], []


print("Checkpoint functions ready.")
# Out:
# Checkpoint functions ready.

# %%
def validation(epoch_iterator_val, global_step):
    """Run inference on all validation volumes. Returns mean Dice and per-class Dice."""
    model.eval()
    dice_metric.reset()
    dice_metric_cls.reset()

    with torch.no_grad():
        for batch in epoch_iterator_val:
            val_inputs = batch['image'].to(device)
            val_labels = batch['label'].to(device)

            with torch.amp.autocast('cuda'):
                val_outputs = sliding_window_inference(
                    val_inputs,
                    roi_size=(96, 96, 96),
                    sw_batch_size=2,   # 2 windows in parallel — fits T4 16GB
                    predictor=model,
                    overlap=0.7,       # 70% overlap = smoother predictions at boundaries
                )

            # Convert to one-hot encoding for Dice computation
            val_labels_conv  = [post_label(x) for x in decollate_batch(val_labels)]
            val_outputs_conv = [post_pred(x)  for x in decollate_batch(val_outputs)]

            dice_metric(y_pred=val_outputs_conv, y=val_labels_conv)
            dice_metric_cls(y_pred=val_outputs_conv, y=val_labels_conv)
            epoch_iterator_val.set_description(f"Validate (step {global_step})")

    mean_dice  = dice_metric.aggregate().item()
    class_dice = dice_metric_cls.aggregate()   # shape: (3,) — one per class
    dice_metric.reset()
    dice_metric_cls.reset()

    print(f"  Mean Dice  : {mean_dice:.4f}")
    print(f"  BG         : {class_dice[0]:.4f}  (always near 1.0 — not meaningful)")
    print(f"  Vessel     : {class_dice[1]:.4f}  (most important — thin tubular structures)")
    print(f"  Tumor      : {class_dice[2]:.4f}  (starts 0.0, rises after ~1000 steps)")
    return mean_dice, class_dice.tolist()


print("Validation function ready.")
# Out:
# Validation function ready.

# %%
def train(global_step, train_loader, dice_val_best, global_step_best,
          epoch_loss_values, metric_values, class_dice_history):
    """One epoch of training. Returns updated training state."""
    model.train()
    epoch_loss = 0
    step = 0

    epoch_iterator = tqdm(
        train_loader,
        desc=f"Training ({global_step}/{max_iterations})",
        dynamic_ncols=True,
    )

    for step, batch in enumerate(epoch_iterator):
        step += 1
        x = batch['image'].to(device)   # shape: (num_samples, 1, 96, 96, 96)
        y = batch['label'].to(device)   # shape: (num_samples, 1, 96, 96, 96)

        # 1. Forward pass with mixed precision
        with torch.amp.autocast('cuda'):
            logit_map = model(x)                    # shape: (num_samples, 3, 96, 96, 96)
            loss = loss_function(logit_map, y)      # scalar

        # 2. Backward pass
        scaler.scale(loss).backward()
        epoch_loss += loss.item()

        # 3. Unscale → clip → optimizer step
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad()

        # 4. Update LR schedule + clear cache
        scheduler.step()
        torch.cuda.empty_cache()

        current_lr = optimizer.param_groups[0]['lr']
        epoch_iterator.set_description(
            f"Training ({global_step}/{max_iterations}) "
            f"loss={loss.item():.5f} lr={current_lr:.2e}"
        )

        # 5. Periodic evaluation and checkpoint save
        if (global_step % eval_num == 0 and global_step != 0) or global_step == max_iterations:
            print(f"\n--- Evaluation at step {global_step} ---")
            val_iter = tqdm(val_loader, desc="Validating...", dynamic_ncols=True)
            dice_val, class_dice = validation(val_iter, global_step)

            epoch_loss_values.append(epoch_loss / step)
            metric_values.append(dice_val)
            class_dice_history.append(class_dice)

            if dice_val > dice_val_best:
                dice_val_best    = dice_val
                global_step_best = global_step
                torch.save(model.state_dict(), BEST_MODEL_PATH)
                print(f"  NEW BEST  Dice: {dice_val_best:.4f}  at step {global_step}")
            else:
                print(f"  No improvement. Best: {dice_val_best:.4f}  Current: {dice_val:.4f}")

            save_checkpoint(
                global_step, dice_val_best, global_step_best,
                epoch_loss_values, metric_values, class_dice_history
            )

        global_step += 1
        if global_step > max_iterations:
            break

    return global_step, dice_val_best, global_step_best, epoch_loss_values, metric_values, class_dice_history


print("Training function ready.")
# Out:
# Training function ready.

# %%
# Load checkpoint (resumes if found, starts fresh if not)
global_step, dice_val_best, global_step_best, epoch_loss_values, metric_values, class_dice_history = load_checkpoint()

print(f"\nStarting from step  : {global_step}")
print(f"Target steps        : {max_iterations}")
print(f"Steps remaining     : {max_iterations - global_step}")
print(f"Eval/save every     : {eval_num} steps")
print(f"Pretrained weights  : {weight_valid if 'weight_valid' in dir() else False}")
print()

# Main training loop
# Each call to train() processes the full training set once (one epoch)
while global_step < max_iterations:
    global_step, dice_val_best, global_step_best, epoch_loss_values, metric_values, class_dice_history = train(
        global_step, train_loader, dice_val_best, global_step_best,
        epoch_loss_values, metric_values, class_dice_history
    )

print(f"\n{'='*50}")
print(f"Training complete!")
print(f"Best Dice  : {dice_val_best:.4f}")
print(f"At step    : {global_step_best}")
print(f"{'='*50}")
# Out:
# Checkpoint found : /kaggle/input/datasets/vivekkumar30112006/hepatic-checkpoint/training_checkpoint.pth
# File size        : 754 MB
# Resuming from step 3000 | Best Dice so far: 0.6307
#
# Starting from step  : 3000
# Target steps        : 5000
# Steps remaining     : 2000
# Eval/save every     : 500 steps
# Pretrained weights  : False
# Training (3000/5000) loss=0.44057 lr=1.96e-05:   0%|          | 0/283 [00:27<?, ?it/s]
# --- Evaluation at step 3000 ---
# Validating...:   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/monai/inferers/utils.py:226: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:347.)
#   win_data = torch.cat([inputs[win_slice] for win_slice in unravel_slice]).to(sw_device)
# /usr/local/lib/python3.12/dist-packages/monai/inferers/utils.py:370: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:347.)
#   out[idx_zm] += p
#
# Validate (step 3000):   0%|          | 0/20 [01:41<?, ?it/s]
# Validate (step 3000):   5%|▌         | 1/20 [01:41<32:05, 101.32s/it]
# Validate (step 3000):   5%|▌         | 1/20 [03:42<32:05, 101.32s/it]
# Validate (step 3000):  10%|█         | 2/20 [03:42<33:55, 113.11s/it]
# Validate (step 3000):  10%|█         | 2/20 [05:46<33:55, 113.11s/it]
# Validate (step 3000):  15%|█▌        | 3/20 [05:46<33:24, 117.90s/it]
# Validate (step 3000):  15%|█▌        | 3/20 [06:38<33:24, 117.90s/it]
# Validate (step 3000):  20%|██        | 4/20 [06:38<24:28, 91.79s/it]
# Validate (step 3000):  20%|██        | 4/20 [09:34<24:28, 91.79s/it]
# Validate (step 3000):  25%|██▌       | 5/20 [09:34<30:37, 122.50s/it]
# Validate (step 3000):  25%|██▌       | 5/20 [11:58<30:37, 122.50s/it]
# Validate (step 3000):  30%|███       | 6/20 [11:58<30:17, 129.79s/it]
# Validate (step 3000):  30%|███       | 6/20 [14:21<30:17, 129.79s/it]
# Validate (step 3000):  35%|███▌      | 7/20 [14:21<29:00, 133.87s/it]
# Validate (step 3000):  35%|███▌      | 7/20 [17:25<29:00, 133.87s/it]
# Validate (step 3000):  40%|████      | 8/20 [17:25<29:59, 149.97s/it]
# Validate (step 3000):  40%|████      | 8/20 [20:16<29:59, 149.97s/it]
# Validate (step 3000):  45%|████▌     | 9/20 [20:16<28:40, 156.41s/it]
# Validate (step 3000):  45%|████▌     | 9/20 [23:02<28:40, 156.41s/it]
# Validate (step 3000):  50%|█████     | 10/20 [23:02<26:33, 159.31s/it]
# Validate (step 3000):  50%|█████     | 10/20 [24:15<26:33, 159.31s/it]
# Validate (step 3000):  55%|█████▌    | 11/20 [24:15<19:58, 133.16s/it]
# Validate (step 3000):  55%|█████▌    | 11/20 [26:05<19:58, 133.16s/it]
# Validate (step 3000):  60%|██████    | 12/20 [26:05<16:48, 126.00s/it]
# Validate (step 3000):  60%|██████    | 12/20 [28:56<16:48, 126.00s/it]
# Validate (step 3000):  65%|██████▌   | 13/20 [28:56<16:16, 139.48s/it]
# Validate (step 3000):  65%|██████▌   | 13/20 [31:08<16:16, 139.48s/it]
# Validate (step 3000):  70%|███████   | 14/20 [31:08<13:44, 137.48s/it]
# Validate (step 3000):  70%|███████   | 14/20 [32:41<13:44, 137.48s/it]
# Validate (step 3000):  75%|███████▌  | 15/20 [32:41<10:19, 124.00s/it]
# Validate (step 3000):  75%|███████▌  | 15/20 [35:29<10:19, 124.00s/it]
# Validate (step 3000):  80%|████████  | 16/20 [35:29<09:08, 137.10s/it]
# Validate (step 3000):  80%|████████  | 16/20 [37:18<09:08, 137.10s/it]
# Validate (step 3000):  85%|████████▌ | 17/20 [37:18<06:26, 128.85s/it]
# Validate (step 3000):  85%|████████▌ | 17/20 [40:40<06:26, 128.85s/it]
# Validate (step 3000):  90%|█████████ | 18/20 [40:40<05:01, 150.73s/it]
# Validate (step 3000):  90%|█████████ | 18/20 [46:08<05:01, 150.73s/it]
# Validate (step 3000):  95%|█████████▌| 19/20 [46:08<03:24, 204.03s/it]
# Validate (step 3000):  95%|█████████▌| 19/20 [48:34<03:24, 204.03s/it]
# Validate (step 3000): 100%|██████████| 20/20 [48:34<00:00, 145.75s/it]
#   Mean Dice  : 0.6307
#   BG         : 0.9990  (always near 1.0 — not meaningful)
#   Vessel     : 0.5626  (most important — thin tubular structures)
#   Tumor      : 0.3305  (starts 0.0, rises after ~1000 steps)
#   NEW BEST  Dice: 0.6307  at step 3000
# Training (3000/5000) loss=0.44057 lr=1.96e-05:   0%|          | 1/283 [49:03<230:36:42, 2943.98s/it]
#   Checkpoint saved → /kaggle/working/training_checkpoint.pth  (754 MB)
# Training (3282/5000) loss=2.24357 lr=1.09e-05: 100%|██████████| 283/283 [1:04:19<00:00, 13.64s/it]
# Training (3500/5000) loss=0.50804 lr=5.86e-06:  77%|███████▋  | 217/283 [12:08<04:56,  4.50s/it]
# --- Evaluation at step 3500 ---
# Validating...:   0%|          | 0/20 [00:00<?, ?it/s]
# Validate (step 3500):   0%|          | 0/20 [01:44<?, ?it/s]
# Validate (step 3500):   5%|▌         | 1/20 [01:44<33:14, 104.99s/it]
# Validate (step 3500):   5%|▌         | 1/20 [03:46<33:14, 104.99s/it]
# Validate (step 3500):  10%|█         | 2/20 [03:46<34:26, 114.78s/it]
# Validate (step 3500):  10%|█         | 2/20 [05:50<34:26, 114.78s/it]
# Validate (step 3500):  15%|█▌        | 3/20 [05:50<33:41, 118.90s/it]
# Validate (step 3500):  15%|█▌        | 3/20 [06:42<33:41, 118.90s/it]
# Validate (step 3500):  20%|██        | 4/20 [06:42<24:37, 92.35s/it]
# Validate (step 3500):  20%|██        | 4/20 [09:39<24:37, 92.35s/it]
# Validate (step 3500):  25%|██▌       | 5/20 [09:39<30:42, 122.86s/it]
# Validate (step 3500):  25%|██▌       | 5/20 [12:02<30:42, 122.86s/it]
# Validate (step 3500):  30%|███       | 6/20 [12:02<30:20, 130.04s/it]
# Validate (step 3500):  30%|███       | 6/20 [14:25<30:20, 130.04s/it]
# Validate (step 3500):  35%|███▌      | 7/20 [14:25<29:02, 134.00s/it]
# Validate (step 3500):  35%|███▌      | 7/20 [17:29<29:02, 134.00s/it]
# Validate (step 3500):  40%|████      | 8/20 [17:29<30:01, 150.10s/it]
# Validate (step 3500):  40%|████      | 8/20 [20:20<30:01, 150.10s/it]
# Validate (step 3500):  45%|████▌     | 9/20 [20:20<28:40, 156.43s/it]
# Validate (step 3500):  45%|████▌     | 9/20 [23:05<28:40, 156.43s/it]
# Validate (step 3500):  50%|█████     | 10/20 [23:05<26:32, 159.23s/it]
# Validate (step 3500):  50%|█████     | 10/20 [24:19<26:32, 159.23s/it]
# Validate (step 3500):  55%|█████▌    | 11/20 [24:19<19:57, 133.09s/it]
# Validate (step 3500):  55%|█████▌    | 11/20 [26:08<19:57, 133.09s/it]
# Validate (step 3500):  60%|██████    | 12/20 [26:08<16:47, 125.91s/it]
# Validate (step 3500):  60%|██████    | 12/20 [28:59<16:47, 125.91s/it]
# Validate (step 3500):  65%|██████▌   | 13/20 [28:59<16:15, 139.38s/it]
# Validate (step 3500):  65%|██████▌   | 13/20 [31:12<16:15, 139.38s/it]
# Validate (step 3500):  70%|███████   | 14/20 [31:12<13:44, 137.38s/it]
# Validate (step 3500):  70%|███████   | 14/20 [32:44<13:44, 137.38s/it]
# Validate (step 3500):  75%|███████▌  | 15/20 [32:44<10:19, 123.94s/it]
# Validate (step 3500):  75%|███████▌  | 15/20 [35:32<10:19, 123.94s/it]
# Validate (step 3500):  80%|████████  | 16/20 [35:32<09:08, 137.15s/it]
# Validate (step 3500):  80%|████████  | 16/20 [37:22<09:08, 137.15s/it]
# Validate (step 3500):  85%|████████▌ | 17/20 [37:22<06:26, 128.84s/it]
# Validate (step 3500):  85%|████████▌ | 17/20 [40:43<06:26, 128.84s/it]
# Validate (step 3500):  90%|█████████ | 18/20 [40:43<05:01, 150.61s/it]
# Validate (step 3500):  90%|█████████ | 18/20 [46:11<05:01, 150.61s/it]
# Validate (step 3500):  95%|█████████▌| 19/20 [46:11<03:23, 203.85s/it]
# Validate (step 3500):  95%|█████████▌| 19/20 [48:37<03:23, 203.85s/it]
# Validate (step 3500): 100%|██████████| 20/20 [48:37<00:00, 145.87s/it]
#   Mean Dice  : 0.6298
#   BG         : 0.9990  (always near 1.0 — not meaningful)
#   Vessel     : 0.5600  (most important — thin tubular structures)
#   Tumor      : 0.3304  (starts 0.0, rises after ~1000 steps)
#   No improvement. Best: 0.6307  Current: 0.6298
# Training (3500/5000) loss=0.50804 lr=5.86e-06:  77%|███████▋  | 218/283 [1:00:47<15:52:36, 879.34s/it]
#   Checkpoint saved → /kaggle/working/training_checkpoint.pth  (754 MB)
# Training (3565/5000) loss=0.59071 lr=4.69e-06: 100%|██████████| 283/283 [1:04:09<00:00, 13.60s/it]
# Training (3817/5000) loss=1.16387 lr=1.65e-06:  89%|████████▉ | 252/283 [13:35<01:13,  2.38s/it]

# %%
if len(epoch_loss_values) == 0:
    print("No data yet — run Cell 12 first.")
else:
    x = [eval_num * (i + 1) for i in range(len(epoch_loss_values))]

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Loss curve
    axes[0].set_title("Training Loss", fontsize=13)
    axes[0].plot(x, epoch_loss_values, 'b-o', linewidth=2, markersize=5)
    axes[0].set_xlabel("Training Step")
    axes[0].set_ylabel("DiceCE Loss")
    axes[0].grid(True, alpha=0.3)
    if len(epoch_loss_values) > 1:
        axes[0].annotate(f"Final: {epoch_loss_values[-1]:.4f}",
                         xy=(x[-1], epoch_loss_values[-1]),
                         xytext=(-60, 15), textcoords='offset points')

    # Mean Dice curve
    axes[1].set_title("Validation Mean Dice", fontsize=13)
    axes[1].plot(x, metric_values, 'g-o', linewidth=2, markersize=5)
    if dice_val_best > 0:
        axes[1].axhline(y=dice_val_best, color='red', linestyle='--',
                        label=f"Best: {dice_val_best:.4f} @ step {global_step_best}")
        axes[1].legend(fontsize=10)
    axes[1].set_ylim(0, 1)
    axes[1].set_xlabel("Training Step")
    axes[1].set_ylabel("Mean Dice Score")
    axes[1].grid(True, alpha=0.3)

    # Per-class Dice curve
    if len(class_dice_history) > 0:
        vessel = [c[1] for c in class_dice_history]
        tumor  = [c[2] for c in class_dice_history]
        x2     = x[:len(vessel)]
        axes[2].set_title("Per-Class Dice (Vessel vs Tumor)", fontsize=13)
        axes[2].plot(x2, vessel, 'r-o', linewidth=2, markersize=5, label=f"Vessel (best: {max(vessel):.4f})")
        axes[2].plot(x2, tumor,  'b-o', linewidth=2, markersize=5, label=f"Tumor  (best: {max(tumor):.4f})")
        axes[2].set_ylim(0, 1)
        axes[2].set_xlabel("Training Step")
        axes[2].legend(fontsize=10)
        axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(os.path.join(WORK_DIR, 'training_curves.png'), dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved to {WORK_DIR}training_curves.png")

# %%
if not os.path.exists(BEST_MODEL_PATH):
    print("Best model not saved yet — run Cell 12 first.")
else:
    model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=device))
    model.eval()
    print(f"Loaded best model. Best Dice: {dice_val_best:.4f} at step {global_step_best}")

    case_num = 0  # change 0–19 to see different validation cases

    with torch.no_grad():
        sample     = val_ds[case_num]
        val_inputs = torch.unsqueeze(sample['image'], 0).to(device)
        val_labels = torch.unsqueeze(sample['label'], 0).to(device)

        with torch.amp.autocast('cuda'):
            val_outputs = sliding_window_inference(
                val_inputs, (96, 96, 96), 2, model, overlap=0.7
            )

    # Find a slice with vessel or tumor annotation
    label_np  = val_labels.cpu().numpy()[0, 0]
    annotated = np.where(label_np.sum(axis=(0, 1)) > 0)[0]
    if len(annotated) > 0:
        vis_slice = int(annotated[len(annotated) // 2])
        print(f"Found {len(annotated)} annotated slices — showing middle one: {vis_slice}")
    else:
        vis_slice = label_np.shape[-1] // 2
        print(f"No annotation found — showing middle slice: {vis_slice}")

    pred = torch.argmax(val_outputs, dim=1).detach().cpu().numpy()

    fig, axes = plt.subplots(1, 3, figsize=(18, 6))

    axes[0].set_title("CT Image", fontsize=13)
    axes[0].imshow(val_inputs.cpu().numpy()[0, 0, :, :, vis_slice], cmap='gray')
    axes[0].axis('off')

    axes[1].set_title("Ground Truth\n(0=BG  1=Vessel  2=Tumor)", fontsize=13)
    im = axes[1].imshow(
        val_labels.cpu().numpy()[0, 0, :, :, vis_slice],
        cmap='nipy_spectral', vmin=0, vmax=2
    )
    plt.colorbar(im, ax=axes[1], shrink=0.7)
    axes[1].axis('off')

    axes[2].set_title("Model Prediction", fontsize=13)
    im = axes[2].imshow(
        pred[0, :, :, vis_slice],
        cmap='nipy_spectral', vmin=0, vmax=2
    )
    plt.colorbar(im, ax=axes[2], shrink=0.7)
    axes[2].axis('off')

    plt.suptitle(
        f"Validation case {case_num} | Slice {vis_slice} | "
        f"Best Dice: {dice_val_best:.4f} at step {global_step_best}",
        fontsize=12
    )
    plt.tight_layout()
    plt.savefig(
        os.path.join(WORK_DIR, f'prediction_case_{case_num}.png'),
        dpi=150, bbox_inches='tight'
    )
    plt.show()
    print(f"Saved to {WORK_DIR}")

# %%
print("=" * 60)
print("   EXPERIMENT SUMMARY")
print("=" * 60)
print(f"  Dataset          : MSD Task08 Hepatic Vessel")
print(f"  Train volumes    : {len(train_files)}")
print(f"  Val volumes      : {len(val_files)}")
print()
print(f"  Model            : SwinUNETR")
print(f"  Feature size     : 48  (SwinUNETR-Base)")
print(f"  Parameters       : 62,186,757")
print(f"  Pretrained       : {weight_valid if 'weight_valid' in dir() else False}")
print()
print(f"  Loss             : DiceCELoss (Dice + CrossEntropy)")
print(f"  Optimizer        : AdamW  lr=1e-4  wd=1e-5")
print(f"  LR Schedule      : LinearWarmup({warmup_steps}) + CosineAnnealing → 1e-6")
print(f"  Grad clipping    : max_norm=1.0")
print(f"  Mixed precision  : FP16 (GradScaler)")
print()
print(f"  Input patch      : 96 × 96 × 96 voxels")
print(f"  Patches/volume   : {num_samples}")
print(f"  HU window        : [-175, 250]")
print(f"  Voxel spacing    : 1mm × 1mm × 1mm (isotropic)")
print(f"  Val overlap      : 0.7  (70% sliding window overlap)")
print()
print(f"  Max iterations   : {max_iterations}")
print(f"  Eval every       : {eval_num} steps")
print(f"  Est. train time  : ~14 hours  (2 Kaggle sessions)")
print()
print("-" * 60)
print(f"  Steps completed  : {global_step}")
print(f"  Best Mean Dice   : {dice_val_best:.4f}")
print(f"  Best at step     : {global_step_best}")
if len(class_dice_history) > 0 and len(metric_values) > 0:
    best_idx = metric_values.index(max(metric_values))
    bd       = class_dice_history[best_idx]
    print(f"  Best Vessel Dice : {bd[1]:.4f}")
    print(f"  Best Tumor Dice  : {bd[2]:.4f}")
print(f"  Checkpoint       : {CHECKPOINT_PATH}")
print(f"  Best model       : {BEST_MODEL_PATH}")
print("=" * 60)
